# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (2000, 21)

# %%
df.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# min       0.000000     2.000000     0.100000    80.000000     1.000000  ...
# 25%       0.000000    16.000000     0.200000   109.000000     3.000000  ...
# 50%       1.000000    32.000000     0.500000   141.000000     4.000000  ...
# 75%       1.000000    48.000000     0.800000   170.000000     7.000000  ...
# max       1.000000    64.000000     1.000000   200.000000     8.000000  ...
#
#          px_height     px_width          ram         sc_h         sc_w  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean    645.108000  1251.515500  2124.213000    12.306500     5.767000
# std     443.780811   432.199447  1084.732044     4.213245     4.356398
# min       0.000000   500.000000   256.000000     5.000000     0.000000
# 25%     282.750000   874.750000  1207.500000     9.000000     2.000000
# 50%     564.000000  1247.000000  2146.500000    12.000000     5.000000
# 75%     947.250000  1633.000000  3064.500000    16.000000     9.000000
# max    1960.000000  1998.000000  3998.000000    19.000000    18.000000
#
#          talk_time      three_g  touch_screen         wifi  price_range
# count  2000.000000  2000.000000   2000.000000  2000.000000  2000.000000
# mean     11.011000     0.761500      0.503000     0.507000     1.500000
# std       5.463955     0.426273      0.500116     0.500076     1.118314
# min       2.000000     0.000000      0.000000     0.000000     0.000000
# 25%       6.000000     1.000000      0.000000     0.000000     0.750000
# 50%      11.000000     1.000000      1.000000     1.000000     1.500000
# 75%      16.000000     1.000000      1.000000     1.000000     2.250000
# max      20.000000     1.000000      1.000000     1.000000     3.000000
#
# [8 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
#  18  touch_screen   2000 non-null   int64
#  19  wifi           2000 non-null   int64
#  20  price_range    2000 non-null   int64
# dtypes: float64(2), int64(19)
# memory usage: 328.2 KB

# %%
plt.figure(figsize = (24,12))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.barplot(x = 'price_range', y = 'battery_power', data = df)
plt.show()

# %%
plt.figure(figsize = (12,6))
plt.subplot(1,2,1)
sns.barplot(x = 'price_range', y = 'px_height', data=df, palette = 'Reds')
plt.subplot(1,2,2)
sns.barplot(x = 'price_range', y = 'px_width', data=df, palette = 'Blues')
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.barplot(x = 'price_range', y = 'ram', data = df)
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.countplot(x='three_g', hue='price_range', data=df, palette='pink')

plt.show()

# %%
plt.figure(figsize = (12,6))
sns.countplot(x='four_g', hue='price_range', data=df, palette='ocean')
plt.show()

# %%
plt.figure(figsize = (12,6))
sns.lineplot(x = 'price_range', y = 'int_memory', data=df, hue='dual_sim')
plt.show()

# %%
x = df.drop(['price_range'], axis = 1)
y = df['price_range']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state = 0)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

for i in range(5, 201, 5):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train, y_train)
    temp = knn.score(x_train, y_train)
    predictions = knn.predict(x_test)
    accu = accuracy_score(y_test, predictions)
    print("For neighbours =", i, "knn score = "+ str(temp) + " accuracy =", str(accu))
# Out:
# For neighbours = 5 knn score = 0.9442857142857143 accuracy = 0.925
# For neighbours = 10 knn score = 0.9457142857142857 accuracy = 0.935
# For neighbours = 15 knn score = 0.9378571428571428 accuracy = 0.9416666666666667
# For neighbours = 20 knn score = 0.9342857142857143 accuracy = 0.94
# For neighbours = 25 knn score = 0.9314285714285714 accuracy = 0.94
# For neighbours = 30 knn score = 0.9257142857142857 accuracy = 0.9333333333333333
# For neighbours = 35 knn score = 0.93 accuracy = 0.9266666666666666
# For neighbours = 40 knn score = 0.9285714285714286 accuracy = 0.925
# For neighbours = 45 knn score = 0.93 accuracy = 0.92
# For neighbours = 50 knn score = 0.9257142857142857 accuracy = 0.925
# For neighbours = 55 knn score = 0.9235714285714286 accuracy = 0.9233333333333333
# For neighbours = 60 knn score = 0.9214285714285714 accuracy = 0.9216666666666666
# For neighbours = 65 knn score = 0.9207142857142857 accuracy = 0.915
# For neighbours = 70 knn score = 0.9164285714285715 accuracy = 0.915
# For neighbours = 75 knn score = 0.9171428571428571 accuracy = 0.915
# For neighbours = 80 knn score = 0.915 accuracy = 0.915
# For neighbours = 85 knn score = 0.9135714285714286 accuracy = 0.91
# For neighbours = 90 knn score = 0.9114285714285715 accuracy = 0.9133333333333333
# For neighbours = 95 knn score = 0.91 accuracy = 0.9083333333333333
# For neighbours = 100 knn score = 0.91 accuracy = 0.91
# For neighbours = 105 knn score = 0.9064285714285715 accuracy = 0.91
# For neighbours = 110 knn score = 0.9035714285714286 accuracy = 0.9083333333333333
# For neighbours = 115 knn score = 0.9035714285714286 accuracy = 0.9066666666666666
# For neighbours = 120 knn score = 0.9028571428571428 accuracy = 0.9016666666666666
# For neighbours = 125 knn score = 0.8964285714285715 accuracy = 0.9066666666666666
# For neighbours = 130 knn score = 0.8985714285714286 accuracy = 0.9016666666666666
# For neighbours = 135 knn score = 0.8992857142857142 accuracy = 0.8983333333333333
# For neighbours = 140 knn score = 0.8957142857142857 accuracy = 0.895
# For neighbours = 145 knn score = 0.8942857142857142 accuracy = 0.89
# For neighbours = 150 knn score = 0.8928571428571429 accuracy = 0.8916666666666667
# For neighbours = 155 knn score = 0.8942857142857142 accuracy = 0.895
# For neighbours = 160 knn score = 0.895 accuracy = 0.895
# For neighbours = 165 knn score = 0.8942857142857142 accuracy = 0.8883333333333333
# For neighbours = 170 knn score = 0.8892857142857142 accuracy = 0.89
# For neighbours = 175 knn score = 0.8857142857142857 accuracy = 0.8916666666666667
# For neighbours = 180 knn score = 0.8864285714285715 accuracy = 0.895
# For neighbours = 185 knn score = 0.8864285714285715 accuracy = 0.89
# For neighbours = 190 knn score = 0.8835714285714286 accuracy = 0.89
# For neighbours = 195 knn score = 0.8814285714285715 accuracy = 0.8883333333333333
# For neighbours = 200 knn score = 0.8807142857142857 accuracy = 0.885

# %%
knn = KNeighborsClassifier(n_neighbors=15)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=15)

# %%
knn.score(x_train, y_train)
# Out:
# 0.9378571428571428

# %%
predictions = knn.predict(x_test)

# %%
accuracy_score(y_test, predictions)
# Out:
# 0.9416666666666667

# %%
test_df = pd.read_csv('test.csv')
test_df.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# 1          7        1             0     0
# 2         10        0             1     1
# 3          7        1             1     0
# 4          7        1             0     1
#
# [5 rows x 21 columns]

# %%
test_df.shape
# Out:
# (1000, 21)

# %%
test_df = test_df.drop(['id'], axis = 1)
test_df.shape
# Out:
# (1000, 20)

# %%
test_pred = knn.predict(test_df)

# %%
test_df['predicted_price'] = test_pred

# %%
test_df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1043     1          1.8         1  14       0           5    0.1
# 1            841     1          0.5         1   4       1          61    0.8
# 2           1807     1          2.8         0   1       0          27    0.9
# 3           1546     0          0.5         1  18       1          25    0.5
# 4           1434     0          1.4         0  11       1          49    0.5
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        193        3  ...        226      1412  3476    12     7          2
# 1        191        5  ...        746       857  3895     6     0          7
# 2        186        3  ...       1270      1366  2396    17    10         10
# 3         96        8  ...        295      1752  3893    10     0          7
# 4        108        6  ...        749       810  1773    15     8          7
#
#    three_g  touch_screen  wifi  predicted_price
# 0        0             1     0                3
# 1        1             0     0                3
# 2        0             1     1                2
# 3        1             1     0                3
# 4        1             0     1                1
#
# [5 rows x 21 columns]
